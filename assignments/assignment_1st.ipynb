# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %matplotlib inline

# %%
img = cv2.imread('../images/364917a8bc4abdfe92f7bfa4cda8cf30.jpg')

# %%
plt.imshow(img)

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
draw_img = cv2.rectangle(fix_img, pt1=(1300,500), pt2=(1600,800), color=(0,0,255), thickness=5)

# %%
plt.imshow(draw_img)

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
vertices = np.array([ [750,500], [900, 500], [825,350] ], dtype=np.int32)

# %%
vertices.shape
# Out:
# (3, 2)

# %%
pts = vertices.reshape((-1,1,2))

# %%
plt.imshow(cv2.polylines(fix_img, [pts], isClosed=True, color=(0,0,255), thickness=4))
