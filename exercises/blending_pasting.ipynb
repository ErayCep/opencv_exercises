# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img1 = cv2.imread('../images/364917a8bc4abdfe92f7bfa4cda8cf30.jpg')
fix_img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.imread('../images/EWMn4QzWAAAO08f.jpg')
fix_img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# %%
img1.shape
# Out:
# (1333, 2000, 3)

# %%
fix_img2 = cv2.resize(fix_img2, (900,600))
plt.imshow(fix_img2)

# %%
fix_img1 = cv2.resize(fix_img1, (900,600))
plt.imshow(fix_img1)

# %%
blended = cv2.addWeighted(src1=fix_img1, alpha=0.5, src2=fix_img2, beta=0.5, gamma=0)

# %%
plt.imshow(blended)

# %%
plt.imshow(fix_img1)

# %%
img1 = cv2.imread('../images/364917a8bc4abdfe92f7bfa4cda8cf30.jpg')
fix_img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.imread('../images/EWMn4QzWAAAO08f.jpg')
fix_img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img1)

# %%
plt.imshow(fix_img2)

# %%
fix_img1.shape
# Out:
# (1333, 2000, 3)

# %%
fix_img2.shape
# Out:
# (842, 595, 3)

# %%
x_offset = 0
y_offset = 0

# %%
x_end = x_offset + fix_img2.shape[1]
y_end = y_offset + fix_img2.shape[0]

# %%
fix_img1[y_offset:y_end, x_offset:x_end] = fix_img2

# %%
plt.imshow(fix_img1)

# %%
img1 = cv2.imread('../images/364917a8bc4abdfe92f7bfa4cda8cf30.jpg')
fix_img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.imread('../images/EWMn4QzWAAAO08f.jpg')
fix_img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# %%
fix_img2 = cv2.resize(fix_img2, (500,800))

# %%
fix_img1.shape
# Out:
# (1333, 2000, 3)

# %%
fix_img2.shape
# Out:
# (800, 500, 3)

# %%
x_offset = 2000 - 500
y_offset = 1333 - 800

# %%
rows, cols, channels = fix_img2.shape

# %%
print(rows, cols, channels)
# Out:
# 800 500 3

# %%
plt.imshow(fix_img1[y_offset:1333, x_offset:2000])

# %%
gray_img2 = cv2.cvtColor(fix_img2, cv2.COLOR_RGB2GRAY)
plt.imshow(gray_img2, cmap='gray')

# %%
mask_inv = cv2.bitwise_not(gray_img2)
plt.imshow(mask_inv, cmap='gray')

# %%
import numpy as np

# %%
white_background = np.full(fix_img2.shape, 255, dtype=np.uint8)

# %%
bk = cv2.bitwise_or(src1=white_background,src2=white_background, mask=mask_inv)

# %%
bk.shape
# Out:
# (800, 500, 3)

# %%
plt.imshow(bk)

# %%
fg = cv2.bitwise_or(fix_img2,fix_img2, mask=mask_inv)

# %%
plt.imshow(fg)

# %%
final_roi = cv2.bitwise_or(roi, fg)
