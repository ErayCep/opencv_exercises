# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('../images/364917a8bc4abdfe92f7bfa4cda8cf30.jpg')

# %%
plt.imshow(img)

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)

# %%
hsv_img = cv2.cvtColor(fix_img, cv2.COLOR_RGB2HSV)
plt.imshow(hsv_img)
