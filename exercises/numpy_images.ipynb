# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open('/Users/eraycep/Documents/CVFolder/images/364917a8bc4abdfe92f7bfa4cda8cf30.jpg')

# %%
pic_arr = np.asarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()

# %%
#plt.imshow(pic_red[:, :, 0], cmap='turbo')

# %%
#plt.imshow(pic_red[:, :, 0], cmap='gray')

# %%
#plt.imshow(pic_red[:, :, 1], cmap='gray')

# %%
#plt.imshow(pic_red[:, :, 2], cmap='gray')

# %%
pic_red[:, :, 1] = 0

# %%
plt.imshow(pic_red)
