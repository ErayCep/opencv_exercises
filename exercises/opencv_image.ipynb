# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('./images/364917a8bc4abdfe92f7bfa4cda8cf30.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (1333, 2000, 3)

# %%
fix_img = cv2.resize(fix_img, (2000//2, 1333//2))

# %%
plt.imshow(fix_img)
